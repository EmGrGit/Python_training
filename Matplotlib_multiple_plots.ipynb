# %% [markdown]
# <a href="https://colab.research.google.com/github/EmGrGit/Python_training/blob/main/Matplotlib_multiple_plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = 'https://raw.githubusercontent.com/cloudacademy/data-visualization-with-python-using-matplotlib/master/data/gapminder.csv'
df = pd.read_csv(url)
df_usa = df.query("Country =='United States'").reset_index(drop=True)
df_china = df.query("Country =='China'").reset_index(drop=True)

# %%
fig, ax = plt.subplots()
ax.plot(df_usa['Year'], df_usa['gdp'], linestyle='-', color='b', label='USA')
ax.plot(df_china['Year'], df_china['gdp'], linestyle='-', color='r', label='China')
ax.set_xlabel('Year')
ax.set_ylabel('GDP per capita')
ax.legend(title='Country')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12,10))
ax[0].plot(df_usa['Year'], df_usa['gdp'], linestyle='-', color='b', label='USA')
ax[1].plot(df_china['Year'], df_china['gdp'], linestyle='-', color='r', label='China')
ax[1].set_xlabel('Year')
ax[0].set_ylabel('GDP - USA')
ax[1].set_ylabel('GDP - China')
ax[0].set_title("Evolution of the GDP per capita: USA vs China")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,10))
ax.plot(df_usa['Year'], df_usa['gdp'], linestyle='-', color='b', label='USA')
ax.set_xlabel('Year')
ax.set_ylabel('GDP per capita (USA)')
ax.set_title("Evolution of the GDP per capita")
ax2 = ax.twinx()
ax2.plot(df_china['Year'], df_china['gdp'], linestyle='-', color='r', label='China')
ax2.set_ylabel('GDP per capita (China)')
ax.grid(True)

lines, handles = ax.get_legend_handles_labels()
lines2, handles2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, handles + handles2, loc='best', title='Country')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,10))
ax.plot(df_usa['Year'], df_usa['gdp'], linestyle='-', color='b', label='USA')
ax.set_xlabel('Year')
ax.set_ylabel('GDP per capita (USA)', color='blue')
ax.set_title("Evolution of the GDP per capita")
ax.tick_params('y', colors='b')
ax2 = ax.twinx()
ax2.plot(df_china['Year'], df_china['gdp'], linestyle='-', color='r', label='China')
ax2.set_ylabel('GDP per capita (China)', color='red')
ax2.tick_params('y', colors='r')
ax.grid(True)

plt.show()
